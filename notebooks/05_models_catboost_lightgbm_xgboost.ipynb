# %%
from pathlib import Path

from fertilizer_recommender.infrastructure.utils.config_loader import load_yaml_config
from fertilizer_recommender.infrastructure.repositories.dataset_repository_impl import CsvDatasetRepository
from fertilizer_recommender.domain.entities.fertilizer_features import FertilizerFeaturesSchema
from fertilizer_recommender.application.use_cases.prepare_dataset import PrepareDatasetUseCase

from fertilizer_recommender.infrastructure.ml.models.catboost_multiclass import CatBoostMulticlass
from fertilizer_recommender.infrastructure.tracking.run_name_generator import (
    generate_run_name,
)
from fertilizer_recommender.infrastructure.tracking.mlflow_tracker import MLflowExperimentTracker
from fertilizer_recommender.domain.services.experiment_tracking_service import (
    ExperimentTrackingService
)
from fertilizer_recommender.infrastructure.ml.cv.splitter import make_stratified_kfold
from fertilizer_recommender.application.use_cases.train_with_cv import TrainWithCVUseCase
from fertilizer_recommender.infrastructure.ml.preprocessors.sklearn_transformer import SklearnFeatureTransformer
from fertilizer_recommender.infrastructure.ml.pipelines.training_pipeline import TrainingPipeline


cfg_train = load_yaml_config("../configs/training.yaml")
cfg_models = load_yaml_config("../configs/models.yaml")
cfg_mlflow = load_yaml_config("../configs/mlflow.yaml")

schema = FertilizerFeaturesSchema(
    numeric_features=["Temparature","Humidity","Moisture","Nitrogen","Potassium","Phosphorous"],
    categorical_features=["Soil Type","Crop Type"],
)

repo = CsvDatasetRepository(
    data_dir=Path("../data/raw"),
    train_file=cfg_train["data"]["train_file"],
    test_file=cfg_train["data"]["test_file"],
)

train_df, _ = PrepareDatasetUseCase(
    repo, schema, cfg_train["data"]["target_col"]
).execute()

X = train_df[schema.all_features]
y = train_df[cfg_train["data"]["target_col"]]


EXPERIMENT_NAME = cfg_mlflow["mlflow"]["experiment_name"]
RUN_NAME = generate_run_name(prefix="catboost")

# 🔑 Wiring propre
tracker = MLflowExperimentTracker()
experiment_service = ExperimentTrackingService(tracker)


def splitter_factory():
    return make_stratified_kfold(
        n_splits=cfg_train["training"]["n_splits"],
        seed=cfg_train["project"]["seed"],
    )

def catboost_pipeline_factory():
    return TrainingPipeline(
        transformer=SklearnFeatureTransformer(
            schema.numeric_features,
            schema.categorical_features,
        ),
        model = CatBoostMulticlass(
            **cfg_models["catboost"],
    ),
    )

use_case = TrainWithCVUseCase(
    experiment_service=experiment_service,
    splitter_factory=splitter_factory,
    pipeline_factory=catboost_pipeline_factory,
    top_k=cfg_train["training"]["top_k"],
)

params = {
    "model": "catboost_multinomial",
    "n_splits": cfg_train["training"]["n_splits"],
    "top_k": cfg_train["training"]["top_k"],
    "seed": cfg_train["project"]["seed"],
}

result = use_case.execute(
    X_df=X,
    y=y,
    experiment_name=EXPERIMENT_NAME,
    run_name=RUN_NAME,
    params=params,
)

print("Fold MAP@3:", result.fold_scores)
print("Mean MAP@3:", result.mean_score)
# Out:
# 2026-01-09 16:31:54.954 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:36 - Tracking URI : sqlite://///Users/surelmanda/Downloads/ml-projects/mlflow_central/db/mlruns.db
# 2026-01-09 16:31:54.966 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:37 - Artifact URI : /Users/surelmanda/Downloads/ml-projects/mlflow_central/mlflow_artifacts
# 2026/01/09 16:31:56 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/09 16:31:56 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/09 16:31:56 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/09 16:31:56 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/09 16:31:56 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/09 16:31:56 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026-01-09 16:31:56.148 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_setup:configure:53 - MLflow configuré avec succès.
# 2026-01-09 16:31:56.149 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:__init__:24 - MLflowExperimentTracker prêt.
# 2026-01-09 16:31:56.150 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:__init__:21 - ExperimentTrackingService initialisé.
# 2026-01-09 16:31:56.167 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:start_experiment:28 - Initialisation de l'expérience 'fertilizer_recommender' (run='Catb_2026-01-09_16h31m54s')
# 2026-01-09 16:31:56.180 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:setup_experiment:55 - Expérience active : fertilizer_recommender
# 2026-01-09 16:31:56.476 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:start_run:69 - Run démarrée : Catb_2026-01-09_16h31m54s
# 2026-01-09 16:31:56.478 | DEBUG    | fertilizer_recommender.domain.services.experiment_tracking_service:log_training_context:41 - Enregistrement du contexte d'entraînement pour catboost_multinomial
# 2026-01-09 16:31:56.482 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_params:82 - Paramètres enregistrés : {'model': 'catboost_multinomial', 'n_splits': 5, 'top_k': 3, 'seed': 42}
# 2026-01-09 16:31:58.018 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 1] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 16:31:58.024 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 1] Entraînement du modèle
# 0:	learn: 1.9456421	total: 575ms	remaining: 5m 44s
# 100:	learn: 1.9325330	total: 54.1s	remaining: 4m 27s
# 200:	learn: 1.9235761	total: 1m 42s	remaining: 3m 23s
# 300:	learn: 1.9154718	total: 2m 19s	remaining: 2m 19s
# 400:	learn: 1.9079308	total: 3m 10s	remaining: 1m 34s
# 500:	learn: 1.9008041	total: 3m 53s	remaining: 46.1s
# 2026-01-09 16:36:34.514 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 1] Prédiction et calcul du top-3
# 599:	learn: 1.8940863	total: 4m 30s	remaining: 0us
# 2026-01-09 16:36:37.347 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 1] Score MAP@3 = 0.3137
# 2026-01-09 16:36:37.349 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold1': 0.31374777777783786}
# 2026-01-09 16:36:37.349 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold1': 0.31374777777783786}
# 2026-01-09 16:36:37.647 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 2] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 16:36:37.650 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 2] Entraînement du modèle
# 0:	learn: 1.9456314	total: 503ms	remaining: 5m 1s
# 100:	learn: 1.9322607	total: 42.5s	remaining: 3m 30s
# 200:	learn: 1.9233031	total: 1m 25s	remaining: 2m 49s
# 300:	learn: 1.9152932	total: 2m 7s	remaining: 2m 6s
# 400:	learn: 1.9077401	total: 2m 58s	remaining: 1m 28s
# 500:	learn: 1.9006528	total: 3m 51s	remaining: 45.7s
# 2026-01-09 16:41:19.306 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 2] Prédiction et calcul du top-3
# 599:	learn: 1.8940058	total: 4m 35s	remaining: 0us
# 2026-01-09 16:41:22.878 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 2] Score MAP@3 = 0.3139
# 2026-01-09 16:41:22.881 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold2': 0.3138544444445061}
# 2026-01-09 16:41:22.882 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold2': 0.3138544444445061}
# 2026-01-09 16:41:23.338 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 3] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 16:41:23.347 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 3] Entraînement du modèle
# 0:	learn: 1.9456396	total: 434ms	remaining: 4m 20s
# 100:	learn: 1.9322546	total: 52.5s	remaining: 4m 19s
# 200:	learn: 1.9233820	total: 1m 39s	remaining: 3m 17s
# 300:	learn: 1.9152639	total: 2m 26s	remaining: 2m 25s
# 400:	learn: 1.9078472	total: 3m 12s	remaining: 1m 35s
# 500:	learn: 1.9008975	total: 3m 53s	remaining: 46.1s
# 2026-01-09 16:45:59.651 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 3] Prédiction et calcul du top-3
# 599:	learn: 1.8940866	total: 4m 30s	remaining: 0us
# 2026-01-09 16:46:02.625 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 3] Score MAP@3 = 0.3141
# 2026-01-09 16:46:02.626 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold3': 0.3141477777778367}
# 2026-01-09 16:46:02.627 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold3': 0.3141477777778367}
# 2026-01-09 16:46:02.998 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 4] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 16:46:03.002 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 4] Entraînement du modèle
# 0:	learn: 1.9456366	total: 673ms	remaining: 6m 43s
# 100:	learn: 1.9324193	total: 34.4s	remaining: 2m 49s
# 200:	learn: 1.9234422	total: 1m 7s	remaining: 2m 13s
# 300:	learn: 1.9154473	total: 1m 40s	remaining: 1m 39s
# 400:	learn: 1.9079277	total: 2m 22s	remaining: 1m 10s
# 500:	learn: 1.9008030	total: 2m 59s	remaining: 35.5s
# 599:	learn: 1.8942240	total: 3m 48s	remaining: 0us
# 2026-01-09 16:49:57.525 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 4] Prédiction et calcul du top-3
# 2026-01-09 16:49:59.981 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 4] Score MAP@3 = 0.3148
# 2026-01-09 16:49:59.982 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold4': 0.31481444444450796}
# 2026-01-09 16:49:59.982 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold4': 0.31481444444450796}
# 2026-01-09 16:50:00.258 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 5] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 16:50:00.260 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 5] Entraînement du modèle
# 0:	learn: 1.9456361	total: 485ms	remaining: 4m 50s
# 100:	learn: 1.9323676	total: 1m 1s	remaining: 5m 2s
# 200:	learn: 1.9235457	total: 1m 39s	remaining: 3m 17s
# 300:	learn: 1.9155399	total: 2m 12s	remaining: 2m 11s
# 400:	learn: 1.9080300	total: 2m 44s	remaining: 1m 21s
# 500:	learn: 1.9008205	total: 3m 17s	remaining: 38.9s
# 599:	learn: 1.8940803	total: 4m 3s	remaining: 0us
# 2026-01-09 16:54:09.643 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 5] Prédiction et calcul du top-3
# 2026-01-09 16:54:13.680 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 5] Score MAP@3 = 0.3135
# 2026-01-09 16:54:13.681 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold5': 0.3134988888889468}
# 2026-01-09 16:54:13.681 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold5': 0.3134988888889468}
# 2026-01-09 16:54:13.695 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_mean': 0.31401266666672706}
# 2026-01-09 16:54:13.696 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_mean': 0.31401266666672706}
# 2026-01-09 16:54:13.700 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:close:59 - Fermeture de l'expérience.
# 2026-01-09 16:54:13.701 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:end_run:75 - Fermeture de la run : b38298ce59a947678ac5e1725902c449
# Fold MAP@3: [0.31374777777783786, 0.3138544444445061, 0.3141477777778367, 0.31481444444450796, 0.3134988888889468]
# Mean MAP@3: 0.31401266666672706

# %%
from pathlib import Path

from fertilizer_recommender.infrastructure.utils.config_loader import load_yaml_config
from fertilizer_recommender.infrastructure.repositories.dataset_repository_impl import CsvDatasetRepository
from fertilizer_recommender.domain.entities.fertilizer_features import FertilizerFeaturesSchema
from fertilizer_recommender.application.use_cases.prepare_dataset import PrepareDatasetUseCase

from fertilizer_recommender.infrastructure.ml.models.lightgbm_multiclass import LightGBMMulticlass
from fertilizer_recommender.infrastructure.tracking.run_name_generator import (
    generate_run_name,
)
from fertilizer_recommender.infrastructure.tracking.mlflow_tracker import MLflowExperimentTracker
from fertilizer_recommender.domain.services.experiment_tracking_service import (
    ExperimentTrackingService
)
from fertilizer_recommender.infrastructure.ml.cv.splitter import make_stratified_kfold
from fertilizer_recommender.application.use_cases.train_with_cv import TrainWithCVUseCase
from fertilizer_recommender.infrastructure.ml.preprocessors.sklearn_transformer import SklearnFeatureTransformer
from fertilizer_recommender.infrastructure.ml.pipelines.training_pipeline import TrainingPipeline


cfg_train = load_yaml_config("../configs/training.yaml")
cfg_models = load_yaml_config("../configs/models.yaml")
cfg_mlflow = load_yaml_config("../configs/mlflow.yaml")

schema = FertilizerFeaturesSchema(
    numeric_features=["Temparature","Humidity","Moisture","Nitrogen","Potassium","Phosphorous"],
    categorical_features=["Soil Type","Crop Type"],
)

repo = CsvDatasetRepository(
    data_dir=Path("../data/raw"),
    train_file=cfg_train["data"]["train_file"],
    test_file=cfg_train["data"]["test_file"],
)

train_df, _ = PrepareDatasetUseCase(
    repo, schema, cfg_train["data"]["target_col"]
).execute()

X = train_df[schema.all_features]
y = train_df[cfg_train["data"]["target_col"]]


EXPERIMENT_NAME = cfg_mlflow["mlflow"]["experiment_name"]
RUN_NAME = generate_run_name(prefix="Lightgbm")

# 🔑 Wiring propre
tracker = MLflowExperimentTracker()
experiment_service = ExperimentTrackingService(tracker)


def splitter_factory():
    return make_stratified_kfold(
        n_splits=cfg_train["training"]["n_splits"],
        seed=cfg_train["project"]["seed"],
    )

def lightgbm_pipeline_factory():
    return TrainingPipeline(
        transformer=SklearnFeatureTransformer(
            schema.numeric_features,
            schema.categorical_features,
        ),
        model=LightGBMMulticlass(
            #num_class=len(y.unique()),
            **cfg_models["lightgbm"],
        ),
    )

use_case = TrainWithCVUseCase(
    experiment_service=experiment_service,
    splitter_factory=splitter_factory,
    pipeline_factory=lightgbm_pipeline_factory,
    top_k=cfg_train["training"]["top_k"],
)

params = {
    "model": "lightgbm_multinomial",
    "n_splits": cfg_train["training"]["n_splits"],
    "top_k": cfg_train["training"]["top_k"],
    "seed": cfg_train["project"]["seed"],
}

result = use_case.execute(
    X_df=X,
    y=y,
    experiment_name=EXPERIMENT_NAME,
    run_name=RUN_NAME,
    params=params,
)

print("Fold MAP@3:", result.fold_scores)
print("Mean MAP@3:", result.mean_score)
# Out:
# 2026-01-09 16:59:04.199 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:36 - Tracking URI : sqlite://///Users/surelmanda/Downloads/ml-projects/mlflow_central/db/mlruns.db
# 2026-01-09 16:59:04.206 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:37 - Artifact URI : /Users/surelmanda/Downloads/ml-projects/mlflow_central/mlflow_artifacts
# 2026-01-09 16:59:04.280 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_setup:configure:53 - MLflow configuré avec succès.
# 2026-01-09 16:59:04.282 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:__init__:24 - MLflowExperimentTracker prêt.
# 2026-01-09 16:59:04.285 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:__init__:21 - ExperimentTrackingService initialisé.
# 2026-01-09 16:59:04.309 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:start_experiment:28 - Initialisation de l'expérience 'fertilizer_recommender' (run='Lightgbm_2026-01-09_16h59m04s')
# 2026-01-09 16:59:04.318 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:setup_experiment:55 - Expérience active : fertilizer_recommender
# 2026-01-09 16:59:04.347 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:start_run:69 - Run démarrée : Lightgbm_2026-01-09_16h59m04s
# 2026-01-09 16:59:04.348 | DEBUG    | fertilizer_recommender.domain.services.experiment_tracking_service:log_training_context:41 - Enregistrement du contexte d'entraînement pour lightgbm_multinomial
# 2026-01-09 16:59:04.349 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_params:82 - Paramètres enregistrés : {'model': 'lightgbm_multinomial', 'n_splits': 5, 'top_k': 3, 'seed': 42}
# 2026-01-09 16:59:05.503 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 1] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 16:59:05.504 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 1] Entraînement du modèle
# 2026-01-09 16:59:19.591 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:close:59 - Fermeture de l'expérience.
# 2026-01-09 16:59:19.601 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:end_run:75 - Fermeture de la run : c1585d701bb44881bb1d4adc44052898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 85
#      71 use_case = TrainWithCVUseCase(
#      72     experiment_service=experiment_service,
#      73     splitter_factory=splitter_factory,
#      74     pipeline_factory=lightgbm_pipeline_factory,
#      75     top_k=cfg_train["training"]["top_k"],
#      76 )
#      78 params = {
#      79     "model": "lightgbm_multinomial",
#      80     "n_splits": cfg_train["training"]["n_splits"],
#      81     "top_k": cfg_train["training"]["top_k"],
#      82     "seed": cfg_train["project"]["seed"],
#      83 }
# ---> 85 result = use_case.execute(
#      86     X_df=X,
#      87     y=y,
#      88     experiment_name=EXPERIMENT_NAME,
#      89     run_name=RUN_NAME,
#      90     params=params,
#      91 )
#      93 print("Fold MAP@3:", result.fold_scores)
#      94 print("Mean MAP@3:", result.mean_score)
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/src/fertilizer_recommender/application/use_cases/train_with_cv.py:93, in TrainWithCVUseCase.execute(self, X_df, y, experiment_name, run_name, params)
#      91 self.logger.info(f"[Fold {fold}] Entraînement du modèle")
#      92 pipeline = self.pipeline_factory()
# ---> 93 pipeline.fit(X_tr, y_tr)
#      95 logger.info(f"[Fold {fold}] Prédiction et calcul du top-{self.top_k}")
#      96 proba = pipeline.predict_proba(X_va)
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/src/fertilizer_recommender/infrastructure/ml/pipelines/training_pipeline.py:26, in TrainingPipeline.fit(self, X_df, y)
#      24 def fit(self, X_df, y):
#      25     X = self.transformer.fit_transform(X_df)
# ---> 26     self.model.fit(X, y)
#      27     return self
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/src/fertilizer_recommender/infrastructure/ml/models/lightgbm_multiclass.py:26, in LightGBMMulticlass.fit(self, X, y)
#      25 def fit(self, X, y):
# ---> 26     self.model.fit(X, y)
#      27     return self
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1560, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1557         else:
#    1558             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1560 super().fit(
#    1561     X,
#    1562     _y,
#    1563     sample_weight=sample_weight,
#    1564     init_score=init_score,
#    1565     eval_set=valid_sets,
#    1566     eval_names=eval_names,
#    1567     eval_sample_weight=eval_sample_weight,
#    1568     eval_class_weight=eval_class_weight,
#    1569     eval_init_score=eval_init_score,
#    1570     eval_metric=eval_metric,
#    1571     feature_name=feature_name,
#    1572     categorical_feature=categorical_feature,
#    1573     callbacks=callbacks,
#    1574     init_model=init_model,
#    1575 )
#    1576 return self
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/.venv/lib/python3.11/site-packages/lightgbm/engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File ~/Downloads/ml-projects/Clean-Architecture-MLops/fertilizer_recommender/.venv/lib/python3.11/site-packages/lightgbm/basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
from pathlib import Path

from fertilizer_recommender.infrastructure.utils.config_loader import load_yaml_config
from fertilizer_recommender.infrastructure.repositories.dataset_repository_impl import CsvDatasetRepository
from fertilizer_recommender.domain.entities.fertilizer_features import FertilizerFeaturesSchema
from fertilizer_recommender.application.use_cases.prepare_dataset import PrepareDatasetUseCase

from fertilizer_recommender.infrastructure.ml.models.xgboost_multiclass import XGBoostMulticlass
from fertilizer_recommender.infrastructure.tracking.run_name_generator import (
    generate_run_name,
)
from fertilizer_recommender.infrastructure.tracking.mlflow_tracker import MLflowExperimentTracker
from fertilizer_recommender.domain.services.experiment_tracking_service import (
    ExperimentTrackingService
)
from fertilizer_recommender.infrastructure.ml.cv.splitter import make_stratified_kfold
from fertilizer_recommender.application.use_cases.train_with_cv import TrainWithCVUseCase
from fertilizer_recommender.infrastructure.ml.preprocessors.sklearn_transformer import SklearnFeatureTransformer
from fertilizer_recommender.infrastructure.ml.pipelines.training_pipeline import TrainingPipeline


cfg_train = load_yaml_config("../configs/training.yaml")
cfg_models = load_yaml_config("../configs/models.yaml")
cfg_mlflow = load_yaml_config("../configs/mlflow.yaml")

schema = FertilizerFeaturesSchema(
    numeric_features=["Temparature","Humidity","Moisture","Nitrogen","Potassium","Phosphorous"],
    categorical_features=["Soil Type","Crop Type"],
)

repo = CsvDatasetRepository(
    data_dir=Path("../data/raw"),
    train_file=cfg_train["data"]["train_file"],
    test_file=cfg_train["data"]["test_file"],
)

train_df, _ = PrepareDatasetUseCase(
    repo, schema, cfg_train["data"]["target_col"]
).execute()

X = train_df[schema.all_features]
y = train_df[cfg_train["data"]["target_col"]]


EXPERIMENT_NAME = cfg_mlflow["mlflow"]["experiment_name"]
RUN_NAME = generate_run_name(prefix="xgboost")

# 🔑 Wiring propre
tracker = MLflowExperimentTracker()
experiment_service = ExperimentTrackingService(tracker)


def splitter_factory():
    return make_stratified_kfold(
        n_splits=cfg_train["training"]["n_splits"],
        seed=cfg_train["project"]["seed"],
    )

def xgboost_pipeline_factory():
    return TrainingPipeline(
        transformer=SklearnFeatureTransformer(
            schema.numeric_features,
            schema.categorical_features,
        ),
        model=XGBoostMulticlass(
            #num_class=len(y.unique()),
            **cfg_models["xgboost"],
        ),
    )

use_case = TrainWithCVUseCase(
    experiment_service=experiment_service,
    splitter_factory=splitter_factory,
    pipeline_factory=xgboost_pipeline_factory,
    top_k=cfg_train["training"]["top_k"],
)

params = {
    "model": "xgboost_multinomial",
    "n_splits": cfg_train["training"]["n_splits"],
    "top_k": cfg_train["training"]["top_k"],
    "seed": cfg_train["project"]["seed"],
}

def encodelabel(y):
    #import numpy as np
    from typing import Dict, Any

    #print(np.unique(y))
    map_encod : Dict[Any, int] = {
        '10-26-26': 0,
        '14-35-14': 1,
        '17-17-17': 2,
        '20-20': 3,
        '28-28': 4,
        'DAP': 5,
        'Urea': 6,
    }
    return y.map(map_encod)

def process_input_data(X):
    X_transf = X.copy(deep=True)
    
    for col in X_transf.select_dtypes(exclude="number").columns:
        X_transf[col] = X_transf[col].astype("category")
    
    return X_transf


result = use_case.execute(
    X_df=process_input_data(X),
    y=encodelabel(y),
    experiment_name=EXPERIMENT_NAME,
    run_name=RUN_NAME,
    params=params,
)

print("Fold MAP@3:", result.fold_scores)
print("Mean MAP@3:", result.mean_score)
# Out:
# 2026-01-09 14:08:55.192 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:36 - Tracking URI : sqlite://///Users/surelmanda/Downloads/ml-projects/mlflow_central/db/mlruns.db
# 2026-01-09 14:08:55.198 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:37 - Artifact URI : /Users/surelmanda/Downloads/ml-projects/mlflow_central/mlflow_artifacts
# 2026/01/09 14:08:55 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/09 14:08:55 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/09 14:08:55 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/09 14:08:55 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/09 14:08:55 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/09 14:08:55 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026-01-09 14:08:55.929 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_setup:configure:53 - MLflow configuré avec succès.
# 2026-01-09 14:08:55.929 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:__init__:24 - MLflowExperimentTracker prêt.
# 2026-01-09 14:08:55.930 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:__init__:21 - ExperimentTrackingService initialisé.
# 2026-01-09 14:08:56.075 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:start_experiment:28 - Initialisation de l'expérience 'fertilizer_recommender' (run='Lightgbm_2026-01-09_14h08m55s')
# 2026-01-09 14:08:56.080 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:setup_experiment:55 - Expérience active : fertilizer_recommender
# 2026-01-09 14:08:56.251 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:start_run:69 - Run démarrée : Lightgbm_2026-01-09_14h08m55s
# 2026-01-09 14:08:56.252 | DEBUG    | fertilizer_recommender.domain.services.experiment_tracking_service:log_training_context:41 - Enregistrement du contexte d'entraînement pour xgboost_multinomial
# 2026-01-09 14:08:56.253 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_params:82 - Paramètres enregistrés : {'model': 'xgboost_multinomial', 'n_splits': 5, 'top_k': 3, 'seed': 42}
# 2026-01-09 14:08:56.456 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 1] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 14:08:56.457 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 1] Entraînement du modèle
# 2026-01-09 14:12:20.435 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 1] Prédiction et calcul du top-3
# 2026-01-09 14:12:29.034 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 1] Score MAP@3 = 0.3388
# 2026-01-09 14:12:29.035 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.33875000000008243}
# 2026-01-09 14:12:29.035 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.33875000000008243}
# 2026-01-09 14:12:29.389 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 2] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 14:12:29.390 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 2] Entraînement du modèle
# 2026-01-09 14:15:38.245 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 2] Prédiction et calcul du top-3
# 2026-01-09 14:15:48.882 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 2] Score MAP@3 = 0.3397
# 2026-01-09 14:15:48.883 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.33972777777786334}
# 2026-01-09 14:15:48.883 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.33972777777786334}
# 2026-01-09 14:15:49.389 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 3] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 14:15:49.395 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 3] Entraînement du modèle
# 2026-01-09 14:18:18.324 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 3] Prédiction et calcul du top-3
# 2026-01-09 14:18:26.621 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 3] Score MAP@3 = 0.3397
# 2026-01-09 14:18:26.622 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.3397466666667503}
# 2026-01-09 14:18:26.622 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.3397466666667503}
# 2026-01-09 14:18:26.877 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 4] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 14:18:26.877 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 4] Entraînement du modèle
# 2026-01-09 14:21:31.021 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 4] Prédiction et calcul du top-3
# 2026-01-09 14:21:38.400 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 4] Score MAP@3 = 0.3394
# 2026-01-09 14:21:38.401 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.3393622222223047}
# 2026-01-09 14:21:38.402 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.3393622222223047}
# 2026-01-09 14:21:38.545 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 5] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-09 14:21:38.546 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 5] Entraînement du modèle
# 2026-01-09 14:24:16.482 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 5] Prédiction et calcul du top-3
# 2026-01-09 14:24:23.533 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 5] Score MAP@3 = 0.3403
# 2026-01-09 14:24:23.534 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.34028444444452743}
# 2026-01-09 14:24:23.534 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.34028444444452743}
# 2026-01-09 14:24:23.556 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_mean': 0.33957422222230566}
# 2026-01-09 14:24:23.556 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_mean': 0.33957422222230566}
# 2026-01-09 14:24:23.569 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:close:59 - Fermeture de l'expérience.
# 2026-01-09 14:24:23.571 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:end_run:75 - Fermeture de la run : 6f311f3d3dd748adb93181ceb9a19b34
# Fold MAP@3: [0.33875000000008243, 0.33972777777786334, 0.3397466666667503, 0.3393622222223047, 0.34028444444452743]
# Mean MAP@3: 0.33957422222230566

# %%
from fertilizer_recommender.application.use_cases.evaluate_model import EvaluateModelUseCase

#evaluator = EvaluateModelUseCase(pipeline, top_k=3)
#metrics = evaluator.execute(X_train, y_train.tolist())
#metrics

# %%
#storage = LocalStorage(Path("../artifacts/reports"))
#storage.save_text("hello", "test.txt")
#storage.load_text("test.txt")
