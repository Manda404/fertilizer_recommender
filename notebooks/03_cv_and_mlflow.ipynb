# %%
"""
poetry run mlflow ui \
--backend-store-uri $MLFLOW_TRACKING_URI \
--default-artifact-root $MLFLOW_ARTIFACT_URI



poetry run mlflow ui \
--backend-store-uri $MLFLOW_TRACKING_URI \
--default-artifact-root $MLFLOW_ARTIFACT_URI \
--port 8080


Option,Rôle
poetry run,Exécute la commande mlflow ui dans l'environnement virtuel géré par Poetry.
mlflow ui,Commande pour démarrer le serveur web de l'interface utilisateur MLflow.
--backend-store-uri,"Indique l'emplacement où sont stockées les métadonnées de suivi (expérimentations, runs, métriques)."
--default-artifact-root,"Indique l'emplacement où sont stockés les fichiers d'artefacts (modèles, images, etc.)."
--port NNNN,"C'est l'option clé : elle spécifie le numéro de port (par exemple, 8080) sur lequel le serveur UI doit écouter."
"""
# Out:
# '\npoetry run mlflow ui --backend-store-uri $MLFLOW_TRACKING_URI --default-artifact-root $MLFLOW_ARTIFACT_URI\n\n\n\npoetry run mlflow ui --backend-store-uri $MLFLOW_TRACKING_URI --default-artifact-root $MLFLOW_ARTIFACT_URI --port 8080\n\n\nOption,Rôle\npoetry run,Exécute la commande mlflow ui dans l\'environnement virtuel géré par Poetry.\nmlflow ui,Commande pour démarrer le serveur web de l\'interface utilisateur MLflow.\n--backend-store-uri,"Indique l\'emplacement où sont stockées les métadonnées de suivi (expérimentations, runs, métriques)."\n--default-artifact-root,"Indique l\'emplacement où sont stockés les fichiers d\'artefacts (modèles, images, etc.)."\n--port NNNN,"C\'est l\'option clé : elle spécifie le numéro de port (par exemple, 8080) sur lequel le serveur UI doit écouter."\n'

# %%
from fertilizer_recommender.infrastructure.observability.logger import setup_logger
from loguru import logger

setup_logger(
    project_name="fertilizer_recommender",
    environment="notebook",
    level="DEBUG",
)

logger.info("Logger initialisé depuis le notebook")
# Out:
# 2026-01-08 14:09:56 | INFO | fertilizer_recommender | notebook | 2748173838:<module>:10 | Logger initialisé depuis le notebook

# %%
from pathlib import Path

from fertilizer_recommender.infrastructure.utils.config_loader import load_yaml_config
from fertilizer_recommender.infrastructure.repositories.dataset_repository_impl import CsvDatasetRepository
from fertilizer_recommender.domain.entities.fertilizer_features import FertilizerFeaturesSchema
from fertilizer_recommender.application.use_cases.prepare_dataset import PrepareDatasetUseCase

from fertilizer_recommender.infrastructure.ml.preprocessors.sklearn_transformer import SklearnFeatureTransformer
from fertilizer_recommender.infrastructure.ml.models.baseline_logreg import BaselineLogisticRegression
from fertilizer_recommender.infrastructure.ml.pipelines.training_pipeline import TrainingPipeline

from fertilizer_recommender.infrastructure.ml.cv.splitter import make_stratified_kfold
from fertilizer_recommender.infrastructure.tracking.mlflow_tracker import MLflowExperimentTracker
from fertilizer_recommender.domain.services.experiment_tracking_service import (
    ExperimentTrackingService
)
from fertilizer_recommender.infrastructure.tracking.run_name_generator import (
    generate_run_name,
)
from fertilizer_recommender.application.use_cases.train_with_cv import TrainWithCVUseCase


cfg_train = load_yaml_config("../configs/training.yaml")
cfg_mlflow = load_yaml_config("../configs/mlflow.yaml")

schema = FertilizerFeaturesSchema(
    numeric_features=["Temparature","Humidity","Moisture","Nitrogen","Potassium","Phosphorous"],
    categorical_features=["Soil Type","Crop Type"],
)

repo = CsvDatasetRepository(
    data_dir=Path("../data/raw"),
    train_file=cfg_train["data"]["train_file"],
    test_file=cfg_train["data"]["test_file"],
)

train_df, test_df = PrepareDatasetUseCase(
    repo,
    schema,
    cfg_train["data"]["target_col"]
).execute()

X = train_df[schema.all_features]
y = train_df[cfg_train["data"]["target_col"]]

EXPERIMENT_NAME = "fertilizer_recommender"
RUN_NAME = generate_run_name(prefix="LOGREG")

# 🔑 Wiring propre
tracker = MLflowExperimentTracker()
experiment_service = ExperimentTrackingService(tracker)

def splitter_factory():
    return make_stratified_kfold(
        n_splits=cfg_train["training"]["n_splits"],
        seed=cfg_train["project"]["seed"],
    )

def pipeline_factory():
    return TrainingPipeline(
        transformer=SklearnFeatureTransformer(
            schema.numeric_features,
            schema.categorical_features,
        ),
        model=BaselineLogisticRegression(
            random_state=cfg_train["project"]["seed"],
        ),
    )

use_case = TrainWithCVUseCase(
    experiment_service=experiment_service,
    splitter_factory=splitter_factory,
    pipeline_factory=pipeline_factory,
    top_k=cfg_train["training"]["top_k"],
)

params = {
    "model": "logreg_multinomial",
    "n_splits": cfg_train["training"]["n_splits"],
    "top_k": cfg_train["training"]["top_k"],
    "seed": cfg_train["project"]["seed"],
}

result = use_case.execute(
    X_df=X,
    y=y,
    experiment_name=EXPERIMENT_NAME,
    run_name=RUN_NAME,
    params=params,
)

print("Fold MAP@3:", result.fold_scores)
print("Mean MAP@3:", result.mean_score)
# Out:
# 2026-01-08 16:17:05.651 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:36 - Tracking URI : sqlite://///Users/surelmanda/Downloads/ml-projects/mlflow_central/db/mlruns.db
# 2026-01-08 16:17:05.656 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_setup:__init__:37 - Artifact URI : /Users/surelmanda/Downloads/ml-projects/mlflow_central/mlflow_artifacts
# 2026/01/08 16:17:07 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/08 16:17:07 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/08 16:17:07 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/08 16:17:07 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/08 16:17:07 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/08 16:17:07 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026-01-08 16:17:07.615 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_setup:configure:53 - MLflow configuré avec succès.
# 2026-01-08 16:17:07.616 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:__init__:24 - MLflowExperimentTracker prêt.
# 2026-01-08 16:17:07.617 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:__init__:21 - ExperimentTrackingService initialisé.
# 2026-01-08 16:17:07.659 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:start_experiment:28 - Initialisation de l'expérience 'fertilizer_recommender' (run='LOGREG_2026-01-08_16h17m05s')
# 2026-01-08 16:17:07.684 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:setup_experiment:55 - Expérience active : fertilizer_recommender
# 2026-01-08 16:17:07.977 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:start_run:69 - Run démarrée : LOGREG_2026-01-08_16h17m05s
# 2026-01-08 16:17:07.981 | DEBUG    | fertilizer_recommender.domain.services.experiment_tracking_service:log_training_context:41 - Enregistrement du contexte d'entraînement pour logreg_multinomial
# 2026-01-08 16:17:07.983 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_params:82 - Paramètres enregistrés : {'model': 'logreg_multinomial', 'n_splits': 5, 'top_k': 3, 'seed': 42}
# 2026-01-08 16:17:09.910 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 1] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-08 16:17:09.912 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 1] Entraînement du modèle
# 2026-01-08 16:21:43.734 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 1] Prédiction et calcul du top-3
# 2026-01-08 16:21:45.339 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 1] Score MAP@3 = 0.2871
# 2026-01-08 16:21:45.340 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.287121111111145}
# 2026-01-08 16:21:45.341 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.287121111111145}
# 2026-01-08 16:21:45.786 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 2] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-08 16:21:45.806 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 2] Entraînement du modèle
# 2026-01-08 16:26:35.139 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 2] Prédiction et calcul du top-3
# 2026-01-08 16:26:36.914 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 2] Score MAP@3 = 0.2874
# 2026-01-08 16:26:36.934 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.28742222222225544}
# 2026-01-08 16:26:36.936 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.28742222222225544}
# 2026-01-08 16:26:37.203 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 3] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-08 16:26:37.204 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 3] Entraînement du modèle
# 2026-01-08 16:30:28.198 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 3] Prédiction et calcul du top-3
# 2026-01-08 16:30:29.609 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 3] Score MAP@3 = 0.2860
# 2026-01-08 16:30:29.615 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.28603555555558796}
# 2026-01-08 16:30:29.618 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.28603555555558796}
# 2026-01-08 16:30:29.922 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 4] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-08 16:30:29.923 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 4] Entraînement du modèle
# 2026-01-08 16:36:57.078 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 4] Prédiction et calcul du top-3
# 2026-01-08 16:36:59.005 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 4] Score MAP@3 = 0.2858
# 2026-01-08 16:36:59.012 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.28579888888891736}
# 2026-01-08 16:36:59.014 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.28579888888891736}
# 2026-01-08 16:36:59.427 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:86 - [Fold 5] Démarrage (train=600000 obs, val=150000 obs)
# 2026-01-08 16:36:59.430 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:91 - [Fold 5] Entraînement du modèle
# 2026-01-08 16:40:54.619 | INFO     | fertilizer_recommender.application.use_cases.train_with_cv:execute:95 - [Fold 5] Prédiction et calcul du top-3
# 2026-01-08 16:40:55.394 | SUCCESS  | fertilizer_recommender.application.use_cases.train_with_cv:execute:106 - [Fold 5] Score MAP@3 = 0.2870
# 2026-01-08 16:40:55.395 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_fold': 0.2870288888889217}
# 2026-01-08 16:40:55.396 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_fold': 0.2870288888889217}
# 2026-01-08 16:40:55.448 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:log_evaluation:46 - Métriques d'évaluation : {'map_3_mean': 0.2866813333333655}
# 2026-01-08 16:40:55.449 | DEBUG    | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:log_metrics:86 - Métriques enregistrées : {'map_3_mean': 0.2866813333333655}
# 2026-01-08 16:40:55.456 | INFO     | fertilizer_recommender.domain.services.experiment_tracking_service:close:59 - Fermeture de l'expérience.
# 2026-01-08 16:40:55.457 | INFO     | fertilizer_recommender.infrastructure.tracking.mlflow_tracker:end_run:75 - Fermeture de la run : abd8916b335e4932918f6fafcfaef6dc
# [0.287121111111145, 0.28742222222225544, 0.28603555555558796, 0.28579888888891736, 0.2870288888889217]
# 0.2866813333333655

# %%
from fertilizer_recommender.infrastructure.tracking.run_name_generator import generate_run_name
from fertilizer_recommender.infrastructure.tracking.mlflow_tracker import MLflowExperimentTracker
from fertilizer_recommender.domain.services.experiment_tracking_service import ExperimentTrackingService

EXPERIMENT_NAME = "fertilizer_recommender"
RUN_NAME = generate_run_name(prefix="CATB")
MODEL_NAME = "CatBoost"
print(f"Starting experiment '{EXPERIMENT_NAME}' with run name '{RUN_NAME}'")

print("Expérience et run démarrées")
tracking_service = ExperimentTrackingService(tracker=MLflowExperimentTracker())
tracking_service.start_experiment(
    experiment_name=EXPERIMENT_NAME,
    run_name=RUN_NAME
)

logger.info("Clôture de l'expérience MLflow")
tracking_service.close()
