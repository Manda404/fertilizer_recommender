# %%
from health_lifestyle_diabetes.infrastructure.utils.mlflow_setup import setup_mlflow
from datetime import datetime

# --- 0. Configuration de l'Expérience ---
# Le nom de l'expérience DOIT correspondre à celui utilisé dans setup_mlflow
EXPERIMENT_NAME = "fertilizer_recommender" 
RANDOM_STATE = 42

# La fonction setup_mlflow doit être exécutée au début de votre script principal.
exp_id  = setup_mlflow(experiment_name=EXPERIMENT_NAME, showLog=True)

print(f"Experiment ID: {exp_id}")
